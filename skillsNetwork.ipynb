# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Prashant kashyap</strong>

# %% [markdown]
# student

# %% [markdown]
# <p style="font-style:italic">I am interested in data science because it is fun and creative way of applying mathematics </p>

# %% [markdown]
# <h3>The following code gives volume of sphere for given radius in input </h3>

# %%
def vol(r):
    return 4*3.14*r*r*r;

print(vol(8))
# Out:
# 6430.72

# %% [markdown]
# <hr />
# <hr />
# <hr />
#
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# <ol>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ol>
#
# <s>i am done! bye :( </s>: Died as hero :.)<br>
